# %%
# Installing Transformer Libraries
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
# Web links Handler
import requests

# Backend
import torch

# Image Processing
from PIL import Image

# Transformer and Pretrained Model
from transformers import VisionEncoderDecoderModel, ViTImageProcessor, GPT2TokenizerFast

# Managing loading processsing
from tqdm import tqdm

# Assign available GPU
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Loading a fine-tuned image captioning Transformer Model

# ViT Encoder - Decoder Model
model = VisionEncoderDecoderModel.from_pretrained("nlpconnect/vit-gpt2-image-captioning").to(device)

# Corresponding ViT Tokenizer
tokenizer = GPT2TokenizerFast.from_pretrained("nlpconnect/vit-gpt2-image-captioning")

# Image processor
image_processor = ViTImageProcessor.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
# Out:
# config.json:   0%|          | 0.00/4.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]

# %%
# Accesssing images from the web
import urllib.parse as parse
import os
# Verify url
def check_url(string):
    try:
        result = parse.urlparse(string)
        return all([result.scheme, result.netloc, result.path])
    except:
        return False

# Load an image
def load_image(image_path):
    if check_url(image_path):
        return Image.open(requests.get(image_path, stream=True).raw)
    elif os.path.exists(image_path):
        return Image.open(image_path)

# %%
# Image inference
def get_caption(model, image_processor, tokenizer, image_path):
    image = load_image(image_path)

    # Preprocessing the Image
    img = image_processor(image, return_tensors="pt").to(device)

    # Generating captions
    output = model.generate(**img)

    # decode the output
    caption = tokenizer.batch_decode(output, skip_special_tokens=True)[0]

    return caption

# %%
from google.colab import drive
drive.mount('/content/Drive')
# Out:
# Mounted at /content/Drive

# %%
# !unzip "/content/Drive/MyDrive/testdata.zip"
# Out:
# Archive:  /content/Drive/MyDrive/testdata.zip
#    creating: testdata/
#   inflating: testdata/File 001.jpg
#   inflating: testdata/File 002.jpg
#   inflating: testdata/File 003.jpg
#   inflating: testdata/File 004.jpg
#   inflating: testdata/File 005.jpg
#   inflating: testdata/File 006.jpg
#   inflating: testdata/File 007.jpg
#   inflating: testdata/File 008.jpg
#   inflating: testdata/File 009.jpg
#   inflating: testdata/File 010.jpg
#   inflating: testdata/File 011.jpg
#   inflating: testdata/File 012.jpg
#   inflating: testdata/File 013.jpg
#   inflating: testdata/File 014.jpg
#   inflating: testdata/File 015.jpg
#   inflating: testdata/File 016.jpg
#   inflating: testdata/File 017.jpg
#   inflating: testdata/File 018.jpg
#   inflating: testdata/File 019.jpg
#   inflating: testdata/File 020.jpg
#   inflating: testdata/File 021.jpg
#   inflating: testdata/File 022.jpg
#   inflating: testdata/File 023.jpg
#   inflating: testdata/File 024.jpg
#   inflating: testdata/File 025.jpg
#   inflating: testdata/File 026.jpg
#   inflating: testdata/File 027.jpg
#   inflating: testdata/File 028.jpg
#   inflating: testdata/File 029.jpg
#   inflating: testdata/File 030.jpg
#   inflating: testdata/File 031.jpg
#   inflating: testdata/File 032.jpg
#   inflating: testdata/File 033.jpg
#   inflating: testdata/File 034.jpg
#   inflating: testdata/File 035.jpg
#   inflating: testdata/File 036.jpg
#   inflating: testdata/File 037.jpg
#   inflating: testdata/File 038.jpg
#   inflating: testdata/File 039.jpg
#   inflating: testdata/File 040.jpg
#   inflating: testdata/File 962.jpg
#   inflating: testdata/File 963.jpg
#   inflating: testdata/File 964.jpg
#   inflating: testdata/File 965.jpg
#   inflating: testdata/File 966.jpg
#   inflating: testdata/File 967.jpg
#   inflating: testdata/File 968.jpg
#   inflating: testdata/File 969.jpg
#   inflating: testdata/File 970.jpg
#   inflating: testdata/File 971.jpg
#   inflating: testdata/File 972.jpg
#   inflating: testdata/File 973.jpg
#   inflating: testdata/File 974.jpg
#   inflating: testdata/File 975.jpg
#   inflating: testdata/File 976.jpg
#   inflating: testdata/File 977.jpg
#   inflating: testdata/File 978.jpg
#   inflating: testdata/File 979.jpg
#   inflating: testdata/File 980.jpg
#   inflating: testdata/File 981.jpg
#   inflating: testdata/File 982.jpg
#   inflating: testdata/File 983.jpg
#   inflating: testdata/File 984.jpg
#   inflating: testdata/File 985.jpg
#   inflating: testdata/File 986.jpg
#   inflating: testdata/File 987.jpg
#   inflating: testdata/File 988.jpg
#   inflating: testdata/File 989.jpg
#   inflating: testdata/File 990.jpg
#   inflating: testdata/File 991.jpg
#   inflating: testdata/File 992.jpg
#   inflating: testdata/File 993.jpg
#   inflating: testdata/File 994.jpg
#   inflating: testdata/File 995.jpg
#   inflating: testdata/File 996.jpg
#   inflating: testdata/File 997.jpg
#   inflating: testdata/File 998.jpg
#   inflating: testdata/File 999.jpg

# %%
import glob
filenames = glob.glob("/content/testdata/*.jpg")
filenames.sort()
for image in filenames:
 input_image = Image.open(image)
 caption = get_caption(model, image_processor, tokenizer, image)
 print(image,caption)
 with open('VITGPT2.txt', 'a') as fp:
  fp.write(str([image])+str([caption]))
  fp.write('\n')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# You may ignore this warning if your `pad_token_id` (50256) is identical to the `bos_token_id` (50256), `eos_token_id` (50256), or the `sep_token_id` (None), and your input is not padded.
# /content/testdata/File 001.jpg a man in a suit and tie speaking to a crowd
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /content/testdata/File 002.jpg three children sitting at a table with a laptop
# /content/testdata/File 003.jpg three women sitting at a table with plates of food
# /content/testdata/File 004.jpg a baby sitting in a high chair eating carrots
# /content/testdata/File 005.jpg a man and a woman sitting on a couch
# /content/testdata/File 006.jpg people walking down a street holding umbrellas
# /content/testdata/File 007.jpg people sitting around a table
# /content/testdata/File 008.jpg a little girl standing in a kitchen with a spoon
# /content/testdata/File 009.jpg a small plane with people standing around it
# /content/testdata/File 010.jpg a woman is talking on a cell phone
# /content/testdata/File 011.jpg two women standing next to each other holding umbrellas
# /content/testdata/File 012.jpg a woman sitting at a desk with a laptop
# /content/testdata/File 013.jpg young girls playing soccer on a field
# /content/testdata/File 014.jpg a woman holding a cell phone in her hand
# /content/testdata/File 015.jpg a man and woman are walking through a field
# /content/testdata/File 016.jpg a young child brushing their teeth in a bathroom sink
# /content/testdata/File 017.jpg a woman brushing her teeth with a toothbrush
# /content/testdata/File 018.jpg a baby is laying in a bed with a stuffed animal
# /content/testdata/File 019.jpg a man is standing next to a horse
# /content/testdata/File 020.jpg a man in a suit and tie holding a bowl of food
# /content/testdata/File 021.jpg a man in a suit and tie standing next to a bookcase
# /content/testdata/File 022.jpg three little girls wearing baseball uniforms posing for a picture
# /content/testdata/File 023.jpg a large group of people sitting at a table
# /content/testdata/File 024.jpg a young boy hitting a tennis ball with a racquet
# /content/testdata/File 025.jpg two people sitting on a bench with a park bench
# /content/testdata/File 026.jpg a woman sitting on a couch holding a remote control
# /content/testdata/File 027.jpg a man and woman holding a cake together
# /content/testdata/File 028.jpg a man and a woman are sitting on a bench
# /content/testdata/File 029.jpg a woman walking down a street holding an umbrella
# /content/testdata/File 030.jpg a man sitting on a bench with a blue hat
# /content/testdata/File 031.jpg a man is using a laptop while others look on
# /content/testdata/File 032.jpg a woman in a red jacket and goggles is holding a snowboard
# /content/testdata/File 033.jpg people standing around a street
# /content/testdata/File 034.jpg a man with a teddy bear on his shoulder
# /content/testdata/File 035.jpg people walking down a street with umbrellas
# /content/testdata/File 036.jpg a man eating a sandwich while a woman watches
# /content/testdata/File 037.jpg two people holding an umbrella in the rain
# /content/testdata/File 038.jpg a woman and a dog on a bench
# /content/testdata/File 039.jpg a crowd of children standing around a children's room
# /content/testdata/File 040.jpg people sitting around a table eating
# /content/testdata/File 041.jpg a woman taking a picture of herself in a train
# /content/testdata/File 042.jpg two little girls standing in a field with kites
# /content/testdata/File 043.jpg a couple walking down a sidewalk with an umbrella
# /content/testdata/File 044.jpg two men standing next to each other on a street
# /content/testdata/File 045.jpg a man holding a cell phone in his hand
# /content/testdata/File 046.jpg a woman and a man sitting on a bench
# /content/testdata/File 047.jpg a man and woman preparing food in a kitchen
# /content/testdata/File 048.jpg a group of people holding up food
# /content/testdata/File 049.jpg a woman holding a baby while sitting on a couch
# /content/testdata/File 050.jpg a man and woman standing in a room
# /content/testdata/File 051.jpg a young man sitting at a table with a plate of food
# /content/testdata/File 052.jpg two women sitting at a table with a plate of food
# /content/testdata/File 053.jpg a man and woman sitting at a table
# /content/testdata/File 054.jpg a man in a suit and tie holding a camera
# /content/testdata/File 055.jpg a man and woman are standing at a table
# /content/testdata/File 056.jpg a young boy and a woman are looking at a laptop
# /content/testdata/File 057.jpg a man and woman standing under an umbrella
# /content/testdata/File 058.jpg a woman holding a cell phone in her hand
# /content/testdata/File 059.jpg a man and woman are cutting a cake
# /content/testdata/File 060.jpg a woman and a child in a kitchen
# /content/testdata/File 061.jpg a man and a woman standing next to each other
# /content/testdata/File 062.jpg a man in a suit and tie
# /content/testdata/File 063.jpg a woman wearing a black suit and a black tie
# /content/testdata/File 064.jpg a man sitting at a table with a laptop
# /content/testdata/File 065.jpg a woman holding a cake with a man standing behind her
# /content/testdata/File 066.jpg a young girl holding a kite in a field
# /content/testdata/File 067.jpg a woman sitting on a couch with a laptop
# /content/testdata/File 068.jpg two people walking down a street with umbrellas
# /content/testdata/File 069.jpg a man in a kitchen preparing food on a stove
# /content/testdata/File 070.jpg a woman standing next to a man in a shop
# /content/testdata/File 071.jpg a man in a suit and tie eating a sandwich
# /content/testdata/File 072.jpg a man holding a baseball bat while standing next to a house
# /content/testdata/File 073.jpg a young child sitting at a desk using a laptop
# /content/testdata/File 074.jpg a little boy sitting on a couch with a laptop
# /content/testdata/File 075.jpg a man holding a stop sign while standing in the snow
# /content/testdata/File 076.jpg a street scene with people walking and walking on the sidewalk
# /content/testdata/File 077.jpg people standing around a pier
# /content/testdata/File 078.jpg a woman walking down a wet street holding an umbrella
# /content/testdata/File 079.jpg people walking down a street
# /content/testdata/File 080.jpg a man and woman walking down a street
# /content/testdata/File 081.jpg a woman is walking down the street with her luggage
# /content/testdata/File 082.jpg a woman holding a cell phone in her hand
# /content/testdata/File 083.jpg a man on a cell phone standing on a sidewalk
# /content/testdata/File 084.jpg a woman and child sitting on a couch with a cake
# /content/testdata/File 085.jpg a man sitting on the ground with a laptop
# /content/testdata/File 086.jpg a little girl sitting on a couch eating a treat
# /content/testdata/File 087.jpg two people flying a kite in a field
# /content/testdata/File 088.jpg a man is opening a microwave in a kitchen
# /content/testdata/File 089.jpg people walking down a bridge
# /content/testdata/File 090.jpg a woman in a kitchen preparing food on a counter
# /content/testdata/File 091.jpg a woman is playing frisbee with a group of people
# /content/testdata/File 092.jpg two men eating at a restaurant table
# /content/testdata/File 093.jpg a man in a suit holding a cell phone
# /content/testdata/File 094.jpg a young boy is sitting on the stairs
# /content/testdata/File 095.jpg a man cutting a cake with a knife
# /content/testdata/File 096.jpg a couple posing for a picture in front of the ocean
# /content/testdata/File 097.jpg a little girl eating a donut with a knife
# /content/testdata/File 098.jpg a baby sitting on a wooden floor playing with a keyboard
# /content/testdata/File 099.jpg two men standing in a living room playing a video game
# /content/testdata/File 100.jpg a man is making a pizza in a kitchen
# /content/testdata/File 1000.jpg a cat sitting on the ground next to a car
# /content/testdata/File 1001.jpg a yellow and white train on a track near a fence
# /content/testdata/File 1002.jpg a stop sign and a street sign on a pole
# /content/testdata/File 1003.jpg a sign that says "no parking" on a street
# /content/testdata/File 1004.jpg a sign that says "no parking" on a street
# /content/testdata/File 1005.jpg a street sign on a pole in front of a tall building
# /content/testdata/File 1006.jpg a street sign on a pole with trees
# /content/testdata/File 1007.jpg a stop sign and a street sign on a pole
# /content/testdata/File 1008.jpg a street sign with a street name on it
# /content/testdata/File 1009.jpg a stop sign with a street sign on it
# /content/testdata/File 101.jpg people flying kites in a field
# /content/testdata/File 1010.jpg a tall clock tower with a street sign
# /content/testdata/File 102.jpg a man and woman are posing for a picture
# /content/testdata/File 103.jpg two cats are laying on a bed with a dog
# /content/testdata/File 104.jpg a cat laying on a laptop computer
# /content/testdata/File 105.jpg a cat laying on a rug next to a dog
# /content/testdata/File 106.jpg an elephant standing in a grassy field
# /content/testdata/File 107.jpg a flock of sheep standing next to a gas station
# /content/testdata/File 108.jpg cows grazing on a lush green hillside
# /content/testdata/File 109.jpg a cat sitting in a bath tub with a cat in the bath tub
# /content/testdata/File 110.jpg a brown teddy bear laying on a pillow
# /content/testdata/File 111.jpg a small brown dog wearing a pink bow tie
# /content/testdata/File 112.jpg a giraffe standing in a fenced in area
# /content/testdata/File 113.jpg a cat and a dog are standing outside
# /content/testdata/File 114.jpg a dog with a leash on a leash
# /content/testdata/File 115.jpg giraffes are standing in a field
# /content/testdata/File 116.jpg cows grazing on a hillside
# /content/testdata/File 117.jpg a cat wearing a hat with a green and white stripe
# /content/testdata/File 118.jpg two zebras drinking water from a pond
# /content/testdata/File 119.jpg a bird standing on a beach next to water
# /content/testdata/File 120.jpg a cow and a cow grazing on a grassy field
# /content/testdata/File 121.jpg a cat and a dog are playing together
# /content/testdata/File 122.jpg a brown and white cow with horns standing on a dirt ground
# /content/testdata/File 123.jpg a yellow and green bird sitting on a branch
# /content/testdata/File 124.jpg a large horned cow standing on top of a lush green field
# /content/testdata/File 125.jpg elephants walking down a road
# /content/testdata/File 126.jpg a cat sleeping on a pillow with a cup of coffee
# /content/testdata/File 127.jpg a giraffe standing next to a fence
# /content/testdata/File 128.jpg a dog with a birthday cake on it
# /content/testdata/File 129.jpg a black and white cat laying on a computer keyboard
# /content/testdata/File 130.jpg a cat is sitting on a laptop computer
# /content/testdata/File 131.jpg a cat is laying on the toilet seat
# /content/testdata/File 132.jpg a giraffe standing next to a fence with a baby giraffe
# /content/testdata/File 133.jpg a giraffe standing next to a tree in a zoo
# /content/testdata/File 134.jpg a cat laying on a keyboard next to a mouse
# /content/testdata/File 135.jpg a cat sitting on the ground next to a fence
# /content/testdata/File 136.jpg a dog jumping in the air to catch a frisbee
# /content/testdata/File 137.jpg a dog laying on a bench in the grass
# /content/testdata/File 138.jpg a cat sitting on top of a shoe
# /content/testdata/File 139.jpg a cat standing on a dirt ground next to a tree
# /content/testdata/File 140.jpg a sheep and a goat standing in a field
# /content/testdata/File 141.jpg a giraffe is standing in a grassy field
# /content/testdata/File 142.jpg a dog laying on a bed with its head on the pillow
# /content/testdata/File 143.jpg a black cat laying on the ground next to a tire
# /content/testdata/File 144.jpg a cat laying on a blanket on a bed
# /content/testdata/File 145.jpg sheep are standing in a field
# /content/testdata/File 146.jpg a cat laying on a couch with a cat on the back
# /content/testdata/File 147.jpg two bears walking through a snow covered field
# /content/testdata/File 148.jpg a herd of cattle standing around a man
# /content/testdata/File 149.jpg sheep standing next to each other
# /content/testdata/File 150.jpg two cats are sitting on a ledge near a wall
# /content/testdata/File 151.jpg a black cow and a brown cow standing in a field
# /content/testdata/File 152.jpg a cat sitting on a television screen
# /content/testdata/File 153.jpg a cat is sitting on a laptop computer
# /content/testdata/File 154.jpg elephants walking through a grassy field
# /content/testdata/File 155.jpg a herd of cows standing in a field
# /content/testdata/File 156.jpg a cat laying on top of a keyboard
# /content/testdata/File 157.jpg a herd of sheep grazing in a field
# /content/testdata/File 158.jpg a cat is sitting on a shoe
# /content/testdata/File 159.jpg a cat is sitting on the floor next to a toilet
# /content/testdata/File 160.jpg a duck standing on a sandy beach
# /content/testdata/File 161.jpg two cows standing in a field of grass
# /content/testdata/File 162.jpg a black cat is standing on a sink
# /content/testdata/File 163.jpg a cat laying on top of a skateboard
# /content/testdata/File 164.jpg a white fluffy cat sitting on a blanket
# /content/testdata/File 165.jpg a dog laying in the grass with a frisbee
# /content/testdata/File 166.jpg two giraffes standing in a field next to trees
# /content/testdata/File 167.jpg a dog with a collar on sitting on a bed
# /content/testdata/File 168.jpg a cat laying on top of a pair of shoes
# /content/testdata/File 169.jpg a cat laying on a laptop computer
# /content/testdata/File 170.jpg a dog is laying on the beach
# /content/testdata/File 171.jpg a woman is riding a horse in a dirt field
# /content/testdata/File 172.jpg a stuffed animal is on a field with a truck
# /content/testdata/File 173.jpg a cat sitting on top of a chair in a living room
# /content/testdata/File 174.jpg a small bird perched on top of a car
# /content/testdata/File 175.jpg a cow laying on a bench in a park
# /content/testdata/File 176.jpg a cat and a dog laying on a log
# /content/testdata/File 177.jpg a dog is playing with a frisbee in the snow
# /content/testdata/File 178.jpg two dogs are playing with each other in the street
# /content/testdata/File 179.jpg a dog sitting on a chair in a room
# /content/testdata/File 180.jpg a horse pulling a carriage with a man on it
# /content/testdata/File 181.jpg two small brown and white animals sitting on a table
# /content/testdata/File 182.jpg a dog standing on the side of a road
# /content/testdata/File 183.jpg a dog and a cat playing together
# /content/testdata/File 184.jpg a polar bear is looking at something
# /content/testdata/File 185.jpg a cow standing in a field with a fence
# /content/testdata/File 186.jpg a dog with a frisbee in its mouth
# /content/testdata/File 187.jpg a cat sitting on a table next to a plate
# /content/testdata/File 188.jpg a dog is sniffing a piece of fruit
# /content/testdata/File 189.jpg a cat with a hat on
# /content/testdata/File 190.jpg a black dog laying on a couch with a pillow
# /content/testdata/File 191.jpg cows standing on a street
# /content/testdata/File 192.jpg giraffes are walking in a field
# /content/testdata/File 193.jpg a cat sitting on the floor next to a banana
# /content/testdata/File 194.jpg a horse pulling a carriage down a street
# /content/testdata/File 195.jpg a dog laying on a bed with a blanket
# /content/testdata/File 196.jpg a bird sitting on a chair in a garden
# /content/testdata/File 197.jpg a sheep standing on a fence looking at the camera
# /content/testdata/File 198.jpg a flock of sheep grazing on a dry grass field
# /content/testdata/File 199.jpg a large elephant standing in a zoo enclosure
# /content/testdata/File 200.jpg a black and white dog laying on a bed with a laptop
# /content/testdata/File 201.jpg a large bear laying on top of a pile of rocks
# /content/testdata/File 202.jpg a dog on a skateboard on a sidewalk
# /content/testdata/File 203.jpg a pair of seagulls swimming in the water
# /content/testdata/File 204.jpg a cat sitting in a bowl on a table
# /content/testdata/File 205.jpg a horse standing next to a fence
# /content/testdata/File 206.jpg a cat and a dog laying on a bed
# /content/testdata/File 207.jpg a cat sitting on a desk next to a computer
# /content/testdata/File 208.jpg a herd of sheep grazing in a field
# /content/testdata/File 209.jpg a dog looking out a window at a dog in a window
# /content/testdata/File 210.jpg a woman in a black dress is petting a black dog
# /content/testdata/File 211.jpg a man and a woman riding on the back of an elephant
# /content/testdata/File 212.jpg a man feeding a giraffe at a zoo
# /content/testdata/File 213.jpg a woman is sitting on a bike with a dog
# /content/testdata/File 214.jpg a man is looking at sheep in a field
# /content/testdata/File 215.jpg a man feeding a giraffe at a zoo
# /content/testdata/File 216.jpg a man and a dog are in a field with a cow
# /content/testdata/File 217.jpg a man riding on the back of an elephant
# /content/testdata/File 218.jpg a woman is standing next to an elephant
# /content/testdata/File 219.jpg a woman riding a horse through the water
# /content/testdata/File 220.jpg a man and a cat are sitting on a bed
# /content/testdata/File 221.jpg a man riding on the back of an elephant
# /content/testdata/File 222.jpg a man riding a horse down a street
# /content/testdata/File 223.jpg a cat sitting on a couch next to a remote
# /content/testdata/File 224.jpg a man and a dog on a surfboard in the water
# /content/testdata/File 225.jpg a woman sitting on a chair with a dog
# /content/testdata/File 226.jpg a man holding a dog in his lap
# /content/testdata/File 227.jpg a dog eating a donut with a person
# /content/testdata/File 228.jpg a man riding a horse in a dirt field
# /content/testdata/File 229.jpg a man is standing in a field with a horse
# /content/testdata/File 230.jpg a herd of cattle crossing a road with a man on a horse
# /content/testdata/File 231.jpg a man sitting on top of an elephant
# /content/testdata/File 232.jpg a woman and a cat are laying on a bed
# /content/testdata/File 233.jpg two people riding on the backs of elephants
# /content/testdata/File 234.jpg a man and a dog on a surfboard
# /content/testdata/File 235.jpg a woman petting a horse while a man watches
# /content/testdata/File 236.jpg a man and a woman on a beach with a dog
# /content/testdata/File 237.jpg a man riding a skateboard with a dog
# /content/testdata/File 238.jpg a woman petting a brown horse in a barn
# /content/testdata/File 239.jpg a man is feeding a giraffe at a zoo
# /content/testdata/File 240.jpg a little girl holding a dog in a field
# /content/testdata/File 241.jpg a man catching a frisbee in a park
# /content/testdata/File 242.jpg a woman walking a cow down a street
# /content/testdata/File 243.jpg a horse standing on a dirt road next to a fence
# /content/testdata/File 244.jpg a person riding a horse in a field
# /content/testdata/File 245.jpg a person is holding a cell phone and a cat
# /content/testdata/File 246.jpg a man holding a cat in his arms
# /content/testdata/File 247.jpg a man is holding a horse by a fence
# /content/testdata/File 248.jpg a man and a little girl standing next to a cow
# /content/testdata/File 249.jpg a woman in a hat and a white hat
# /content/testdata/File 250.jpg a woman holding a bird on her shoulder
# /content/testdata/File 251.jpg a man is petting a dog in a pond
# /content/testdata/File 252.jpg a man is leading a horse down a track
# /content/testdata/File 253.jpg a woman walking a dog on the beach
# /content/testdata/File 254.jpg a woman sitting next to a white dog
# /content/testdata/File 255.jpg a man and a dog are playing with a dog
# /content/testdata/File 256.jpg a man riding a horse in a field
# /content/testdata/File 257.jpg a little girl standing in a grassy field with a cow
# /content/testdata/File 258.jpg a man sitting on a couch with a dog
# /content/testdata/File 259.jpg a woman riding a horse in a dirt field
# /content/testdata/File 260.jpg a man and a woman petting a cow
# /content/testdata/File 261.jpg a man is holding a horse by a rope
# /content/testdata/File 262.jpg two men are touching an elephant's trunk
# /content/testdata/File 263.jpg a man riding a horse next to a herd of cattle
# /content/testdata/File 264.jpg a man is pulling a horse with a rope
# /content/testdata/File 265.jpg a woman riding a horse on a beach
# /content/testdata/File 266.jpg a woman in a dress is petting a horse
# /content/testdata/File 267.jpg a woman sitting at a table with a cake
# /content/testdata/File 268.jpg a man holding a dog's mouth while looking at a camera
# /content/testdata/File 269.jpg a cat is sitting on a laptop computer
# /content/testdata/File 270.jpg a person walking with an umbrella on a beach
# /content/testdata/File 271.jpg a man walking down a road with a cow
# /content/testdata/File 272.jpg a woman and a dog are walking down the street
# /content/testdata/File 273.jpg a dog is holding a remote control in its mouth
# /content/testdata/File 274.jpg a horse drawn carriage with a man on it
# /content/testdata/File 275.jpg a man is holding a brown dog in his hand
# /content/testdata/File 276.jpg a woman sitting on the ground with a dog
# /content/testdata/File 277.jpg a man riding a horse while another man watches
# /content/testdata/File 278.jpg a giraffe is feeding a person with a stick
# /content/testdata/File 279.jpg a woman standing next to a brown cow in a barn
# /content/testdata/File 280.jpg a cat is laying on a person's lap
# /content/testdata/File 281.jpg a man is petting a sheep in a field
# /content/testdata/File 282.jpg a woman in a white dress is petting a dog
# /content/testdata/File 283.jpg a woman holding a dog in her arms
# /content/testdata/File 284.jpg a man feeding a giraffe with a spoon
# /content/testdata/File 285.jpg a man in a suit and tie standing next to a elephant
# /content/testdata/File 286.jpg people standing around a horse
# /content/testdata/File 287.jpg a man riding on the back of an elephant
# /content/testdata/File 288.jpg a man riding a horse on the beach
# /content/testdata/File 289.jpg a man standing next to a cow
# /content/testdata/File 290.jpg a horse drawn carriage with a man and woman
# /content/testdata/File 291.jpg two people riding horses on the beach
# /content/testdata/File 292.jpg a man and a baby elephant in the water
# /content/testdata/File 293.jpg a man is touching an elephant's trunk
# /content/testdata/File 294.jpg a woman in a dress with a horse
# /content/testdata/File 295.jpg a woman is petting an elephant with her trunk
# /content/testdata/File 296.jpg a woman riding a horse in a barn
# /content/testdata/File 297.jpg a man sitting on top of an elephant
# /content/testdata/File 298.jpg a woman standing next to a white horse
# /content/testdata/File 299.jpg a little girl walking down a street with a dog
# /content/testdata/File 300.jpg a giraffe standing next to a woman in front of a fence
# /content/testdata/File 301.jpg a man riding on the back of a brown horse
# /content/testdata/File 302.jpg a woman and a dog are sitting on a bench
# /content/testdata/File 303.jpg two people riding on top of an elephant
# /content/testdata/File 304.jpg a man is walking a horse down the street
# /content/testdata/File 305.jpg a man is standing next to a cow
# /content/testdata/File 306.jpg a woman is walking a horse down the street
# /content/testdata/File 307.jpg a man and a dog standing in a yard
# /content/testdata/File 308.jpg people riding on the backs of elephants
# /content/testdata/File 309.jpg people riding on the backs of elephants
# /content/testdata/File 310.jpg a baseball player swinging a bat at a ball
# /content/testdata/File 311.jpg a tennis player is swinging a racket at a ball
# /content/testdata/File 312.jpg a man riding a motorcycle on a race track
# /content/testdata/File 313.jpg a woman standing in the dirt with a group of people
# /content/testdata/File 314.jpg a man on a skateboard doing a trick
# /content/testdata/File 315.jpg a man riding a wave on top of a surfboard
# /content/testdata/File 316.jpg a boy on a skateboard in a dirt field
# /content/testdata/File 317.jpg a man hitting a tennis ball with a tennis racquet
# /content/testdata/File 318.jpg a man is standing next to a group of motorcycles
# /content/testdata/File 319.jpg a large group of people in ski gear posing for a picture
# /content/testdata/File 320.jpg a man riding skis down a snow covered slope
# /content/testdata/File 321.jpg young girls playing soccer on a field
# /content/testdata/File 322.jpg two people playing a video game on a wii
# /content/testdata/File 323.jpg a man hitting a tennis ball with a tennis racquet
# /content/testdata/File 324.jpg a man riding a skateboard down a street
# /content/testdata/File 325.jpg a man jumping a skateboard over a rail
# /content/testdata/File 326.jpg a man riding a skateboard down a sidewalk next to a group of people
# /content/testdata/File 327.jpg a man sitting on a bus looking out the window
# /content/testdata/File 328.jpg a tennis player is playing tennis on a court
# /content/testdata/File 329.jpg a baseball player is about to throw a ball
# /content/testdata/File 330.jpg three baseball players standing on a field
# /content/testdata/File 331.jpg a man riding a wave on top of a surfboard
# /content/testdata/File 332.jpg a man riding a bike with a helmet on
# /content/testdata/File 333.jpg two soccer players are playing soccer on a field
# /content/testdata/File 334.jpg a man is paddle boarding on a body of water
# /content/testdata/File 335.jpg a young boy is in the water with a baby
# /content/testdata/File 336.jpg a man holding a tennis racquet on a tennis court
# /content/testdata/File 337.jpg people are playing frisbee on the beach
# /content/testdata/File 338.jpg a man and woman are standing on a railing
# /content/testdata/File 339.jpg a woman and a child riding a bicycle with a basket
# /content/testdata/File 340.jpg people walking on the beach with surfboards
# /content/testdata/File 341.jpg a boy is doing a trick on a skateboard
# /content/testdata/File 342.jpg a little girl is playing with a toy on a couch
# /content/testdata/File 343.jpg a woman and a child eating a hot dog
# /content/testdata/File 344.jpg a man riding a bike down a street
# /content/testdata/File 345.jpg two young boys playing soccer on a field
# /content/testdata/File 346.jpg a soccer game is being played on a field
# /content/testdata/File 347.jpg a soccer game is being played on a field
# /content/testdata/File 348.jpg a woman standing in front of a table with food
# /content/testdata/File 349.jpg a man is playing soccer on the beach
# /content/testdata/File 350.jpg a man riding a wave on top of a surfboard
# /content/testdata/File 351.jpg a man riding a motorcycle down the street
# /content/testdata/File 352.jpg a woman sitting at a table with a cake
# /content/testdata/File 353.jpg a man is watching a presentation on a television
# /content/testdata/File 354.jpg a bride and groom cutting their wedding cake
# /content/testdata/File 355.jpg a man standing on a platform next to a train
# /content/testdata/File 356.jpg a baseball player swinging a bat at a ball
# /content/testdata/File 357.jpg a baseball player swinging a bat at a ball
# /content/testdata/File 358.jpg a woman riding a horse on a track
# /content/testdata/File 359.jpg a man and a child are surfing on the beach
# /content/testdata/File 360.jpg a man and woman standing on skis in the snow
# /content/testdata/File 361.jpg people standing on a beach with surfboards
# /content/testdata/File 362.jpg men standing around a kitchen
# /content/testdata/File 363.jpg a boy is doing a trick on a skateboard
# /content/testdata/File 364.jpg a man on a skateboard doing a trick
# /content/testdata/File 365.jpg a man riding a motorcycle with a helmet on
# /content/testdata/File 366.jpg a soccer player kicking a soccer ball
# /content/testdata/File 367.jpg a person on a dirt bike riding on a dirt road
# /content/testdata/File 368.jpg two men playing frisbee in a park
# /content/testdata/File 369.jpg a man in a wet suit holding a surfboard
# /content/testdata/File 370.jpg a man in a blue shirt talking on a cell phone
# /content/testdata/File 371.jpg a man wearing a tie and a woman wearing a dress shirt
# /content/testdata/File 372.jpg a man riding a bike with a dog on it
# /content/testdata/File 373.jpg three people standing on a beach with a sunset
# /content/testdata/File 374.jpg a woman is playing tennis on a court
# /content/testdata/File 375.jpg people on skis standing on a snow covered slope
# /content/testdata/File 376.jpg a man holding a tennis racket on a tennis court
# /content/testdata/File 377.jpg two girls are playing soccer on a field
# /content/testdata/File 378.jpg young boys playing soccer on a field
# /content/testdata/File 379.jpg a man is playing tennis with a woman
# /content/testdata/File 380.jpg a man riding a wave on top of a surfboard
# /content/testdata/File 381.jpg a person riding a skateboard down a street
# /content/testdata/File 382.jpg a man in a red jacket is jumping in the air
# /content/testdata/File 383.jpg a soccer game with a girl kicking a soccer ball
# /content/testdata/File 384.jpg a woman holding a tennis racquet on a tennis court
# /content/testdata/File 385.jpg a man on a snowboard is doing a trick
# /content/testdata/File 386.jpg two men playing tennis on a tennis court
# /content/testdata/File 387.jpg a person riding a horse in a dirt field
# /content/testdata/File 388.jpg a motorcycle is parked on the street
# /content/testdata/File 389.jpg a man kicking a soccer ball on a field
# /content/testdata/File 390.jpg a soccer player kicking a soccer ball
# /content/testdata/File 391.jpg a soccer player kicking a soccer ball
# /content/testdata/File 392.jpg a young baseball player swinging a bat at a ball
# /content/testdata/File 393.jpg a baseball player sliding into home plate
# /content/testdata/File 394.jpg a woman is playing soccer with a group of people
# /content/testdata/File 395.jpg a man swinging a bat at a baseball
# /content/testdata/File 396.jpg a baseball player swinging a bat at a ball
# /content/testdata/File 397.jpg a man and woman sitting on a boat
# /content/testdata/File 398.jpg a little girl standing in front of a oven
# /content/testdata/File 399.jpg a snowboarder is in the air above a group of people
# /content/testdata/File 400.jpg a tennis player is jumping to hit the ball
# /content/testdata/File 401.jpg a man is carrying a bicycle on a street
# /content/testdata/File 402.jpg a woman in a white dress playing tennis
# /content/testdata/File 403.jpg people standing on top of a snow covered slope
# /content/testdata/File 404.jpg a man in a yellow shirt is playing soccer
# /content/testdata/File 405.jpg a woman sitting on a couch with a laptop
# /content/testdata/File 406.jpg a living room with a couch, television, and a coffee table
# /content/testdata/File 407.jpg a baseball player swinging a bat at a ball
# /content/testdata/File 408.jpg a man riding a skateboard on top of a cement ramp
# /content/testdata/File 409.jpg a skateboarder is doing a trick in front of a building
# /content/testdata/File 410.jpg a large group of people in a parade
# /content/testdata/File 411.jpg a woman is eating a hot dog with ketchup
# /content/testdata/File 412.jpg a man is preparing food in a grill
# /content/testdata/File 413.jpg a plate of food with vegetables and meat
# /content/testdata/File 414.jpg a pizza with mushrooms and cheese on a stove top
# /content/testdata/File 415.jpg a table topped with bowls of food and a bowl of fruit
# /content/testdata/File 416.jpg a bowl of food with bananas and a spoon
# /content/testdata/File 417.jpg a plate of food with broccoli and other vegetables
# /content/testdata/File 418.jpg a plate of food with vegetables and meat
# /content/testdata/File 419.jpg a sandwich with a side of lettuce and a side of cheese
# /content/testdata/File 420.jpg a man eating a hot dog in a restaurant
# /content/testdata/File 421.jpg a table topped with plates of food
# /content/testdata/File 422.jpg a plate of food with broccoli and meat
# /content/testdata/File 423.jpg a white plate topped with a doughnut covered in sprinkles
# /content/testdata/File 424.jpg a baby sitting at a table eating a piece of cake
# /content/testdata/File 425.jpg a plate of food with a drink and a fork
# /content/testdata/File 426.jpg a plate of food with a salad and a fork
# /content/testdata/File 427.jpg a plate of food with meat, vegetables and rice
# /content/testdata/File 428.jpg a woman holding a pizza in front of a large pizza pan
# /content/testdata/File 429.jpg a pan of broccoli and meat on a stove top
# /content/testdata/File 430.jpg a sandwich with lettuce and tomato on a white plate
# /content/testdata/File 431.jpg a plate of food with broccoli and meat
# /content/testdata/File 432.jpg a man standing in front of a pile of produce
# /content/testdata/File 433.jpg a plate of food with broccoli and meat
# /content/testdata/File 434.jpg a piece of cake with orange slices and a slice of lemon
# /content/testdata/File 435.jpg a plate of food with fruit and nuts
# /content/testdata/File 436.jpg a cat sitting on a table next to a bowl of apples
# /content/testdata/File 437.jpg a plate of food with meat, potatoes, and vegetables
# /content/testdata/File 438.jpg a plate of food with broccoli and a fork
# /content/testdata/File 439.jpg a sandwich and french fries on a plate
# /content/testdata/File 440.jpg a table topped with plates of food and bowls of food
# /content/testdata/File 441.jpg a bowl of vegetables and meat with a spoon
# /content/testdata/File 442.jpg a banana and a bunch of apples on a table
# /content/testdata/File 443.jpg a bowl of food with a spoon and a cup
# /content/testdata/File 444.jpg a frying pan filled with hot dogs and other ingredients
# /content/testdata/File 445.jpg a sandwich with lettuce, carrots, and a pickle
# /content/testdata/File 446.jpg a cutting board with fruit and vegetables on it
# /content/testdata/File 447.jpg a person cutting a piece of bread with a knife
# /content/testdata/File 448.jpg a pot of stew with vegetables and spices
# /content/testdata/File 449.jpg a plate of vegetables on a wooden table
# /content/testdata/File 450.jpg a girl with a plate of donuts
# /content/testdata/File 451.jpg a fruit stand with a variety of fruits and vegetables
# /content/testdata/File 452.jpg a man sitting at a table with a plate of food
# /content/testdata/File 453.jpg a breakfast of eggs, toast, and bacon
# /content/testdata/File 454.jpg a person holding a piece of fruit on a plate
# /content/testdata/File 455.jpg a table topped with a bunch of donuts
# /content/testdata/File 456.jpg a plate of food on a table
# /content/testdata/File 457.jpg a little girl is blowing out the candles on a cake
# /content/testdata/File 458.jpg a grill with hot dogs, onions, and peppers
# /content/testdata/File 459.jpg a little girl is cutting a pizza on a table
# /content/testdata/File 460.jpg a man standing in front of a produce stand
# /content/testdata/File 461.jpg a man is cutting a pizza with a knife
# /content/testdata/File 462.jpg a little boy eating a piece of cake
# /content/testdata/File 463.jpg a plate of food with meat and vegetables
# /content/testdata/File 464.jpg a basket of fruit with apples, oranges, bananas and bananas
# /content/testdata/File 465.jpg a man and woman eating a large slice of pizza
# /content/testdata/File 466.jpg a table topped with plates of food and bowls of vegetables
# /content/testdata/File 467.jpg a little boy eating a sandwich at a table
# /content/testdata/File 468.jpg a woman is holding a box of donuts
# /content/testdata/File 469.jpg a table topped with lots of different types of vegetables
# /content/testdata/File 470.jpg a plate of food with fruit and a glass of orange juice
# /content/testdata/File 471.jpg a plate of food with broccoli and a bottle of wine
# /content/testdata/File 472.jpg a plate of food with a sandwich and a bowl of salad
# /content/testdata/File 473.jpg a sandwich with a side of pickles on a plate
# /content/testdata/File 474.jpg two men sitting at a table with pizza
# /content/testdata/File 475.jpg a family of four preparing food in a kitchen
# /content/testdata/File 476.jpg a display of apples in a box
# /content/testdata/File 477.jpg a plate of food with meat, broccoli and potatoes
# /content/testdata/File 478.jpg a man is standing by a bunch of bananas
# /content/testdata/File 479.jpg a variety of donuts are displayed on a table
# /content/testdata/File 480.jpg a woman sitting at a table with a plate of food
# /content/testdata/File 481.jpg a little girl is eating a piece of pizza
# /content/testdata/File 482.jpg a display of pastries and pastries on a table
# /content/testdata/File 483.jpg a tray of food with carrots, cucumbers, and other vegetables
# /content/testdata/File 484.jpg a piece of chocolate cake with a slice of strawberry on it
# /content/testdata/File 485.jpg a sandwich and a cup of soup on a wooden table
# /content/testdata/File 486.jpg a person cutting a cake on a table
# /content/testdata/File 487.jpg a woman cutting a cake with a knife
# /content/testdata/File 488.jpg a sandwich and a drink on a blue plate
# /content/testdata/File 489.jpg a woman sitting at a table with a pizza
# /content/testdata/File 490.jpg a young boy sitting at a table with a bunch of fruit
# /content/testdata/File 491.jpg a little girl eating a piece of cake
# /content/testdata/File 492.jpg a man is making a mess of food in a kitchen
# /content/testdata/File 493.jpg a woman sitting at a table with a pizza
# /content/testdata/File 494.jpg a table topped with plates of food
# /content/testdata/File 495.jpg a bowl of fruit with bananas, apples, oranges and apples
# /content/testdata/File 496.jpg a bowl of muffins on a table
# /content/testdata/File 497.jpg a market with bananas, oranges, and other fruits
# /content/testdata/File 498.jpg a man and woman cutting a wedding cake
# /content/testdata/File 499.jpg a woman sitting at a table with a plate of food
# /content/testdata/File 500.jpg a little boy eating a piece of cake
# /content/testdata/File 501.jpg two young boys eating a doughnut at a table
# /content/testdata/File 502.jpg a man and woman sitting at a table with plates of food
# /content/testdata/File 503.jpg a woman is blowing out candles on a cake
# /content/testdata/File 504.jpg a man is holding a small child in front of a pizza
# /content/testdata/File 505.jpg a little girl eating a piece of pizza
# /content/testdata/File 506.jpg a woman is holding a sandwich in front of a sandwich shop
# /content/testdata/File 507.jpg a woman sitting at a table with a plate of pizza
# /content/testdata/File 508.jpg a plate of food with a banana and ice cream
# /content/testdata/File 509.jpg a basket of fruit with apples, oranges, bananas, and apples
# /content/testdata/File 510.jpg a man sitting at a table with a plate of food
# /content/testdata/File 511.jpg a train on a track near a fence
# /content/testdata/File 512.jpg a large jetliner flying through a cloudy sky
# /content/testdata/File 513.jpg a large jetliner sitting on top of an airport tarmac
# /content/testdata/File 514.jpg a double decker bus is driving down the street
# /content/testdata/File 515.jpg a street sign on a pole in front of a building
# /content/testdata/File 516.jpg a train on a track near a platform
# /content/testdata/File 517.jpg a train on a track near a forest
# /content/testdata/File 518.jpg a train on a track near a platform
# /content/testdata/File 519.jpg a man riding a motorcycle down a street
# /content/testdata/File 520.jpg a small airplane flying through a cloudy sky
# /content/testdata/File 521.jpg a double decker bus parked next to a green and white double decker bus
# /content/testdata/File 522.jpg a man standing next to an airplane on a runway
# /content/testdata/File 523.jpg a truck is driving down a wet road
# /content/testdata/File 524.jpg a small plane is parked on the runway
# /content/testdata/File 525.jpg a woman is walking past a large jetliner
# /content/testdata/File 526.jpg a white truck with a sign on the side of it
# /content/testdata/File 527.jpg a white car parked in front of a bus
# /content/testdata/File 528.jpg a train is parked at a train station
# /content/testdata/File 529.jpg a small airplane flying through a cloudy sky
# /content/testdata/File 530.jpg a bus is parked on the side of the road
# /content/testdata/File 531.jpg a double decker bus driving down a street
# /content/testdata/File 532.jpg a train is pulling into a train station
# /content/testdata/File 533.jpg a bus is stopped at a bus stop
# /content/testdata/File 534.jpg a red fire truck parked on the side of the road
# /content/testdata/File 535.jpg a truck with a group of people standing around it
# /content/testdata/File 536.jpg a double decker bus with a large advertisement on the side
# /content/testdata/File 537.jpg a red and white plane is on the runway
# /content/testdata/File 538.jpg a double decker bus is parked on the street
# /content/testdata/File 539.jpg a train on a track near a forest
# /content/testdata/File 540.jpg a motorcycle parked in front of a store
# /content/testdata/File 541.jpg a bus is parked at a bus stop
# /content/testdata/File 542.jpg a red and white fire truck parked in a garage
# /content/testdata/File 543.jpg a yellow bus driving down a road next to a mountain
# /content/testdata/File 544.jpg a car parked next to a parking meter
# /content/testdata/File 545.jpg a boat is docked on the water near a dock
# /content/testdata/File 546.jpg a dirt bike race with a bunch of people watching
# /content/testdata/File 547.jpg a person on a motorcycle with a helmet on
# /content/testdata/File 548.jpg a train is on the tracks near a crowd of people
# /content/testdata/File 549.jpg a double decker bus with a mural of a man on it
# /content/testdata/File 550.jpg a fighter jet flying through the air
# /content/testdata/File 551.jpg a red double decker bus driving down a street
# /content/testdata/File 552.jpg a white and blue bus parked on a street
# /content/testdata/File 553.jpg a boat with a man on it is docked in the water
# /content/testdata/File 554.jpg a dog standing on a boat with a bird on it
# /content/testdata/File 555.jpg a man riding a motorcycle on a city street
# /content/testdata/File 556.jpg a blue and white bus parked on the side of the street
# /content/testdata/File 557.jpg a white truck with a sign on the side
# /content/testdata/File 558.jpg a plane flying over a body of water
# /content/testdata/File 559.jpg a woman is riding a bike on the street
# /content/testdata/File 560.jpg a man riding a motorcycle on a race track
# /content/testdata/File 561.jpg four planes flying in formation in the sky
# /content/testdata/File 562.jpg a man riding a dirt bike on a track
# /content/testdata/File 563.jpg a motorcycle parked on the side of a brick building
# /content/testdata/File 564.jpg a double decker bus is parked on the street
# /content/testdata/File 565.jpg a red and white truck and a blue truck
# /content/testdata/File 566.jpg a train is parked at a train station
# /content/testdata/File 567.jpg four airplanes flying in formation in the sky
# /content/testdata/File 568.jpg a blue and white bus is driving down the street
# /content/testdata/File 569.jpg a police officer riding a motorcycle on a city street
# /content/testdata/File 570.jpg a man is standing on a motorcycle in front of a building
# /content/testdata/File 571.jpg a train station with people waiting for the train
# /content/testdata/File 572.jpg a truck with a person on it driving down a road
# /content/testdata/File 573.jpg a large boat docked in a harbor
# /content/testdata/File 574.jpg a woman is standing on a sidewalk near a bus
# /content/testdata/File 575.jpg a red bus parked in a parking lot
# /content/testdata/File 576.jpg a truck with a blue and white stripe on it
# /content/testdata/File 577.jpg a double decker bus is driving down the street
# /content/testdata/File 578.jpg a small boat with a bunch of people on it
# /content/testdata/File 579.jpg a white truck with a blue trailer on the back
# /content/testdata/File 580.jpg a motorcycle parked on the side of a road
# /content/testdata/File 581.jpg a double decker bus is driving down the street
# /content/testdata/File 582.jpg a fire hydrant spraying water into a street
# /content/testdata/File 583.jpg a bicycle parked on the side of the street
# /content/testdata/File 584.jpg two double decker buses parked next to each other
# /content/testdata/File 585.jpg a man sitting in the back of a pickup truck with a dog
# /content/testdata/File 586.jpg a man riding a motorcycle on a street
# /content/testdata/File 587.jpg a street with a bike and a bus on it
# /content/testdata/File 588.jpg two men are flying a plane in the air
# /content/testdata/File 589.jpg a blue and white bus on a street
# /content/testdata/File 590.jpg a large jetliner flying through a blue sky
# /content/testdata/File 591.jpg a blue car is driving down the street
# /content/testdata/File 592.jpg a man riding a motorcycle on a street
# /content/testdata/File 593.jpg a white truck with a white bed and a white trailer
# /content/testdata/File 594.jpg a bus parked on the side of a road
# /content/testdata/File 595.jpg a bus is parked on the side of the road
# /content/testdata/File 596.jpg a large boat docked at a dock
# /content/testdata/File 597.jpg a man sitting on a bicycle next to a parking meter
# /content/testdata/File 598.jpg a herd of elephants walking down a dirt road
# /content/testdata/File 599.jpg a bus parked on the side of the road
# /content/testdata/File 600.jpg a red and white bus driving down a street
# /content/testdata/File 601.jpg a harbor filled with lots of boats and a large body of water
# /content/testdata/File 602.jpg a large jetliner sitting on top of an airport tarmac
# /content/testdata/File 603.jpg a bus parked on the side of a road
# /content/testdata/File 604.jpg a vintage car is parked in a store
# /content/testdata/File 605.jpg a train is stopped at a train station
# /content/testdata/File 606.jpg a bus parked in front of a building
# /content/testdata/File 607.jpg a large jetliner flying through a blue sky
# /content/testdata/File 608.jpg a large jetliner sitting on top of an airport tarmac
# /content/testdata/File 609.jpg a city bus is stopped at a stop light
# /content/testdata/File 610.jpg a bus is driving down the street
# /content/testdata/File 611.jpg a computer mouse sitting on top of a keyboard
# /content/testdata/File 612.jpg a desk with a laptop, monitor, keyboard and mouse
# /content/testdata/File 613.jpg a teddy bear sitting on a chair in a room
# /content/testdata/File 614.jpg a vase filled with yellow flowers sitting on a table
# /content/testdata/File 615.jpg a shelf filled with different colored vases
# /content/testdata/File 616.jpg a clock on a table with a book
# /content/testdata/File 617.jpg a vase filled with pink and purple flowers
# /content/testdata/File 618.jpg a person is holding a kite in a field
# /content/testdata/File 619.jpg a beach with a table and chairs and a umbrella
# /content/testdata/File 620.jpg a blender with a green liquid in it
# /content/testdata/File 621.jpg a cell phone sitting on top of a table
# /content/testdata/File 622.jpg a large group of luggage sitting on top of a table
# ...
# /content/testdata/File 782.jpg a man walking down a brick wall next to a bench
# /content/testdata/File 783.jpg a train on a track near a building
# /content/testdata/File 784.jpg a bedroom with a bed, television, and a lamp
# /content/testdata/File 785.jpg a beach with people sitting on the sand and umbrellas
# /content/testdata/File 786.jpg a train is going down the tracks in a city
# /content/testdata/File 787.jpg a bed with a large bed frame and a large bed frame
# /content/testdata/File 788.jpg a television is on in a room with a shelf
# /content/testdata/File 789.jpg a television sitting on top of a wooden shelf
# /content/testdata/File 790.jpg a dog is sitting on a couch with a red flower
# /content/testdata/File 791.jpg a desk with a laptop, a chair, and a desk lamp
# /content/testdata/File 792.jpg a busy city street with many signs and buildings
# /content/testdata/File 793.jpg a kitchen with a stove, refrigerator, sink and cabinets
# /content/testdata/File 794.jpg a bedroom with a bed, a lamp, and a window
# /content/testdata/File 795.jpg a beach with a row of umbrellas and chairs
# /content/testdata/File 796.jpg a street with people walking and shopping on it
# /content/testdata/File 797.jpg a street light with a clock on it
# /content/testdata/File 798.jpg a living room with a couch, chair, and a tv
# /content/testdata/File 799.jpg a desk with a computer and a book
# /content/testdata/File 800.jpg a bed with a white comforter and a white pillow
# /content/testdata/File 801.jpg a kitchen with a stove, refrigerator, sink and a table
# /content/testdata/File 802.jpg a bathroom with a sink, mirror, and a bathtub
# /content/testdata/File 803.jpg two boats are docked in a river near a building
# /content/testdata/File 804.jpg a kitchen with a stove, oven, and cabinets
# /content/testdata/File 805.jpg a bathroom with a toilet, sink, and mirror
# /content/testdata/File 806.jpg a kitchen with a stove, sink, and cabinets
# /content/testdata/File 807.jpg a tv sitting on top of a wooden table
# /content/testdata/File 808.jpg a living room with a couch, television and a bookcase
# /content/testdata/File 809.jpg a man laying on a bed in a room
# /content/testdata/File 810.jpg a kitchen with a stove, sink, and cabinets
# /content/testdata/File 811.jpg a clock tower with a sky background
# /content/testdata/File 812.jpg a clock tower with a clock on top
# /content/testdata/File 813.jpg a large building with a clock on it
# /content/testdata/File 814.jpg a clock tower with a clock on it's side
# /content/testdata/File 815.jpg a clock tower with a clock on it's side
# /content/testdata/File 816.jpg a young girl holding a umbrella in front of a building
# /content/testdata/File 817.jpg a clock tower with a clock on it's side
# /content/testdata/File 819.jpg a clock tower with a clock on it's side
# /content/testdata/File 820.jpg a large building with a clock on the front
# /content/testdata/File 821.jpg a clock tower with a light on top
# /content/testdata/File 822.jpg a large building with a clock on the side of it
# /content/testdata/File 823.jpg a bus is driving down the road in front of a tall building
# /content/testdata/File 824.jpg a clock tower with a clock on it's side
# /content/testdata/File 825.jpg a clock tower with a clock on top
# /content/testdata/File 826.jpg a large building with a clock on the top
# /content/testdata/File 827.jpg a clock tower with a clock on it's side
# /content/testdata/File 828.jpg a clock tower in front of a building
# /content/testdata/File 829.jpg a clock tower with a clock on top
# /content/testdata/File 830.jpg a church with a clock tower and a sign
# /content/testdata/File 831.jpg a large building with a clock tower
# /content/testdata/File 832.jpg a large clock tower with a white clock on it
# /content/testdata/File 833.jpg a large building with a clock on it
# /content/testdata/File 834.jpg a clock tower with a clock on it's side
# /content/testdata/File 835.jpg a large clock tower towering over a city
# /content/testdata/File 836.jpg a large building with a clock tower
# /content/testdata/File 837.jpg a clock tower with a large clock on top
# /content/testdata/File 838.jpg a large clock tower with a clock on it
# /content/testdata/File 839.jpg a clock tower with a large clock on it
# /content/testdata/File 840.jpg a street sign on a pole in front of a tall building
# /content/testdata/File 841.jpg a clock tower with a clock on top
# /content/testdata/File 842.jpg a church with a clock tower on top of it
# /content/testdata/File 843.jpg a large building with a clock tower and a statue of a man
# /content/testdata/File 844.jpg a clock tower towering over a city
# /content/testdata/File 845.jpg a statue of a man on a horse in front of a building
# /content/testdata/File 846.jpg a clock tower with a clock on top
# /content/testdata/File 847.jpg a large clock tower towering over a city
# /content/testdata/File 848.jpg a clock tower with a clock on it's side
# /content/testdata/File 849.jpg a large building with a clock on the front of it
# /content/testdata/File 850.jpg a large building with a clock on it
# /content/testdata/File 851.jpg a clock tower with a flag on top
# /content/testdata/File 852.jpg a tall clock tower with a clock on it's side
# /content/testdata/File 853.jpg a large clock tower with a large clock on it's side
# /content/testdata/File 854.jpg a clock tower with a clock on top
# /content/testdata/File 855.jpg a clock tower with a window
# /content/testdata/File 856.jpg a clock tower with a clock on top
# /content/testdata/File 857.jpg people walking down a street near a clock tower
# /content/testdata/File 858.jpg a clock tower towering over a city
# /content/testdata/File 859.jpg a clock tower with a clock on top
# /content/testdata/File 860.jpg a large building with a clock tower
# /content/testdata/File 861.jpg a clock tower with a clock on it's side
# /content/testdata/File 862.jpg a clock tower with a clock on it's side
# /content/testdata/File 863.jpg a clock tower in the middle of a city
# /content/testdata/File 864.jpg a clock tower with a clock on it's side
# /content/testdata/File 865.jpg a building with a clock on the front of it
# /content/testdata/File 866.jpg a clock tower with a clock on it's side
# /content/testdata/File 867.jpg a clock tower with a large clock on it
# /content/testdata/File 868.jpg a clock tower with a clock on each side
# /content/testdata/File 869.jpg a clock tower with a clock on it's side
# /content/testdata/File 870.jpg a large building with a clock on the front of it
# /content/testdata/File 871.jpg people are gathered around a large clock tower
# /content/testdata/File 872.jpg a large building with a clock tower
# /content/testdata/File 873.jpg a clock tower with a clock on top
# /content/testdata/File 874.jpg a clock tower in a park with trees
# /content/testdata/File 875.jpg a clock tower with a flag on top of it
# /content/testdata/File 876.jpg a clock tower with a steeple and a steeple with a clock
# /content/testdata/File 877.jpg a woman standing in front of a clock tower
# /content/testdata/File 878.jpg a large building with a clock on it
# /content/testdata/File 879.jpg a horse statue in front of a building
# /content/testdata/File 880.jpg a bus is parked on the side of the road
# /content/testdata/File 881.jpg a large clock tower with a man standing on top of it
# /content/testdata/File 882.jpg a clock tower with a clock on top
# /content/testdata/File 883.jpg a tall building with a clock on it
# /content/testdata/File 884.jpg a clock tower with a clock on each of it's sides
# /content/testdata/File 885.jpg a clock tower with a sky background
# /content/testdata/File 886.jpg a flock of birds flying over a building
# /content/testdata/File 887.jpg a clock tower with a clock on it's side
# /content/testdata/File 888.jpg a large building with a clock tower
# /content/testdata/File 889.jpg a clock tower with a clock on it's side
# /content/testdata/File 890.jpg a large building with a clock on the side of it
# /content/testdata/File 891.jpg a clock tower with a clock on top
# /content/testdata/File 892.jpg a clock tower in the middle of a city
# /content/testdata/File 893.jpg a red bus is parked in front of a church
# /content/testdata/File 894.jpg a clock tower with a clock on it's side
# /content/testdata/File 895.jpg a clock tower with a large clock on it
# /content/testdata/File 896.jpg a clock tower with a sky background
# /content/testdata/File 897.jpg a large building with a clock tower on top
# /content/testdata/File 898.jpg a large brick building with a clock tower
# /content/testdata/File 899.jpg a clock tower with a clock on it's side
# /content/testdata/File 900.jpg a large building with a clock tower
# /content/testdata/File 901.jpg a clock tower with a clock on top
# /content/testdata/File 902.jpg a clock tower with a clock on each of it's sides
# /content/testdata/File 903.jpg a clock tower with a clock on each side
# /content/testdata/File 904.jpg a clock tower with a clock on top
# /content/testdata/File 905.jpg a bus driving past a tall clock tower
# /content/testdata/File 906.jpg a clock tower with a sky background
# /content/testdata/File 907.jpg a large brick building with a large clock on the front
# /content/testdata/File 908.jpg a clock tower with a clock on it's side
# /content/testdata/File 909.jpg a clock tower with a clock on top
# /content/testdata/File 910.jpg a large building with a clock on it
# /content/testdata/File 911.jpg a street sign on a pole in front of a building
# /content/testdata/File 912.jpg a street sign on a pole in front of a building
# /content/testdata/File 913.jpg a street sign with a street name on it
# /content/testdata/File 914.jpg a street sign on a pole in front of a building
# /content/testdata/File 915.jpg a street sign on a pole in front of a house
# /content/testdata/File 916.jpg a sign that says "don't drink" on the side of a road
# /content/testdata/File 917.jpg a street scene with a man walking down the street
# /content/testdata/File 918.jpg a stop sign with a sticker on it
# /content/testdata/File 919.jpg a street sign with a street name on it
# /content/testdata/File 920.jpg a street sign with a street name on it
# /content/testdata/File 921.jpg a sign that says "no parking" on a pole
# /content/testdata/File 922.jpg a man standing in front of a clock on a building
# /content/testdata/File 923.jpg a yellow sign that says "no parking"
# /content/testdata/File 924.jpg a street sign with many different street names
# /content/testdata/File 925.jpg a baseball player swinging a bat at a ball
# /content/testdata/File 926.jpg a street sign on a brick wall
# /content/testdata/File 927.jpg a man standing in front of a sign that says "no parking"
# /content/testdata/File 928.jpg a street sign on a pole in front of a building
# /content/testdata/File 929.jpg a street sign on a pole in front of a tall building
# /content/testdata/File 930.jpg a bus driving down a street with a sign on the side
# /content/testdata/File 931.jpg a sign that says "no parking" on a pole
# /content/testdata/File 932.jpg a street sign on a pole
# /content/testdata/File 933.jpg a sign on a pole in front of a fence
# /content/testdata/File 934.jpg a street sign with a street name on it
# /content/testdata/File 935.jpg a street sign with a street name on it
# /content/testdata/File 936.jpg a street sign with a sign that says "no parking"
# /content/testdata/File 937.jpg a street sign on a pole in front of a house
# /content/testdata/File 938.jpg a white wall with a blue sign on it
# /content/testdata/File 939.jpg a sign that says "no parking" on a street
# /content/testdata/File 940.jpg a street sign with a street name on it
# /content/testdata/File 941.jpg a stop sign with a street sign on it
# /content/testdata/File 942.jpg a man and woman standing next to a cow
# /content/testdata/File 943.jpg a sign that says "no parking" on a pole
# /content/testdata/File 944.jpg a street sign with a street name on it
# /content/testdata/File 945.jpg a man riding skis down a snow covered slope
# /content/testdata/File 946.jpg a clock on a sign on a building
# /content/testdata/File 947.jpg a man swinging a tennis racquet at a ball
# /content/testdata/File 948.jpg a street sign with a street name on it
# /content/testdata/File 949.jpg a stuffed bear and a stuffed bear doll are in a toy bed
# /content/testdata/File 950.jpg a plane flying over a sign that says "stop war"
# /content/testdata/File 951.jpg a sign that says "no parking" on a street
# /content/testdata/File 952.jpg a red truck with a red roof on a street
# /content/testdata/File 953.jpg a street sign on a pole in front of a building
# /content/testdata/File 954.jpg a bridge over a river with a sign that says "riverbank"
# /content/testdata/File 955.jpg a street sign on a pole in front of a house
# /content/testdata/File 956.jpg a person walking down a street holding an umbrella
# /content/testdata/File 957.jpg a street sign on a pole in front of a building
# /content/testdata/File 958.jpg a stop sign with a street sign on top
# /content/testdata/File 959.jpg a street sign with a blue sky
# /content/testdata/File 960.jpg a street sign with a power line attached to it
# /content/testdata/File 961.jpg a street sign with a street name on it
# /content/testdata/File 962.jpg a sign that is on a pole
# /content/testdata/File 963.jpg a white truck is parked on the side of the street
# /content/testdata/File 964.jpg a street corner with a sign that says "stop"
# /content/testdata/File 965.jpg a motorcycle rally with a group of people standing around it
# /content/testdata/File 966.jpg a street scene with a bus and a truck
# /content/testdata/File 967.jpg a street sign on a pole with trees
# /content/testdata/File 968.jpg a sign that says "no parking" on a street
# /content/testdata/File 969.jpg a street sign with a street name on it
# /content/testdata/File 970.jpg a sign that says "no parking" on a building
# /content/testdata/File 971.jpg a sign that says "no parking" on a pole
# /content/testdata/File 972.jpg a street sign with a street name on it
# /content/testdata/File 973.jpg a street sign that says "no parking"
# /content/testdata/File 974.jpg a sign that says "no swimming" on a beach
# /content/testdata/File 975.jpg a sign that says "no parking" on a street
# /content/testdata/File 976.jpg a man standing in front of a motorcycle
# /content/testdata/File 977.jpg a street sign on a pole in front of a building
# /content/testdata/File 978.jpg a stop sign with a street sign above it
# /content/testdata/File 979.jpg a sign that says "no parking" on a street
# /content/testdata/File 980.jpg a street sign on a pole in front of a building
# /content/testdata/File 981.jpg a street sign with a tree
# /content/testdata/File 982.jpg a woman walking down a street next to a stop sign
# /content/testdata/File 983.jpg a street scene with a man walking down the street
# /content/testdata/File 984.jpg a street sign with a street name and a street name
# /content/testdata/File 985.jpg a street sign with a blue sky
# /content/testdata/File 986.jpg a sign that says "no parking" on a highway
# /content/testdata/File 987.jpg a sign that says "no parking" on a street
# /content/testdata/File 988.jpg a street sign on a pole in a city
# /content/testdata/File 989.jpg a man is riding a bike on a street
# /content/testdata/File 990.jpg a street sign with a street name on it
# /content/testdata/File 991.jpg a street sign on a pole in front of a building
# /content/testdata/File 992.jpg a street sign on a pole on a street
# /content/testdata/File 993.jpg a green street sign on a pole with palm trees
# /content/testdata/File 994.jpg a woman walking down a street with a sign
# /content/testdata/File 995.jpg a street sign with a street name and a sign for a street
# /content/testdata/File 996.jpg a parking meter with a sign on it
# /content/testdata/File 997.jpg a street sign with a street name on it
# /content/testdata/File 998.jpg a stop sign with a street sign on it
# /content/testdata/File 999.jpg a street sign with a street name on it
